# %% [markdown]
# # Programs of Singly LinkedList

# %% [markdown]
# ### CREATION OF NODE

# %%
class Node:
    def __init__(self):
        self.info = None
        self.next = None
node = Node()
node.info = "My First Node"
print(node)
print(node.info)
# Out:
# <__main__.Node object at 0x00000154AED605E0>
# My First Node

# %% [markdown]
# ### CREATION OF LINKED LIST

# %%
class LinkedList:
    def __init__(self):
        self.start=None
SLL=LinkedList()
print(SLL)
# Out:
# <__main__.LinkedList object at 0x00000154AED60A30>

# %% [markdown]
# ### CREATE A LINKEDLIST TO STORE NAMES OF FRIENDS

# %%
class Node:
    def __init__(self):
        self.info=None
        self.next=None

class LinkedList:
    def __init__(self):
        self.start=None
    
    def display(self):
        temp=self.start
        while(temp.next!= None):
            print(temp.info,end="-->")
            temp=temp.next
        print(temp.info)
        
SLL=LinkedList()
node1 = Node()
node1.info = "Nisha"
node2 = Node()
node2.info = "Unnati"
node3 = Node()
node3.info = "Shivani"
node4 = Node()
node4.info = "Vikas"
SLL.start = node1
node1.next = node2
node2.next = node3
node3.next = node4
SLL.display()
# Out:
# Nisha-->Unnati-->Shivani-->Vikas

# %% [markdown]
# ### Perform CREATION, INSERTION, DELETION SORTING REVERAL AND SEARCHING IN LINKEDLIST

# %%
class Node:
    def __init__(self):
        self.info = None
        self.next = None
        
class Linkedlist:
    def __init__(self):
        self.start = None 
    
    def create(self):
        while(1):
            node = Node()
            node.info = input("Enter info: ")
            if(self.start == None):
                self.start = node
            else:
                temp.next = node
            temp = node 
            choice = input("Do u want to next node? yes/no : ")
            if(choice=="no"):
                break
        print("Linkedlist created successfully.")
          
    def insert_at_beg(self):
        if(self.start == None):
            print("No Linkedlist exists.")
        else:
            node = Node()
            node.info = input("Enter element which u want to insert at beginning: ")
            node.next = self.start 
            self.start = node
        print("Insert element at beginning successfully.")
    
    def insert_at_last(self):
        if(self.start == None):
            print("No Linkedlist exists.")
        else:
            temp = self.start 
            while(temp.next!=None):
                temp = temp.next 
            node = Node()
            node.info = input("Enter element which u want to insert at last: ")
            temp.next = node
        print("Insert element at last successfully.")
    
    def insert_after_desired_node(self,elem):
        if(self.start == None):
            print("No Linkedlist exists.")
        else:
            temp = self.start
            while(temp.next is not None and temp.info!=elem):
                temp = temp.next
            if(temp.next is None):
                print("Element not found")
            else:
                node=Node()
                node.info = input("Enter element which u want to insert after node: ")
                node.next = temp.next
                temp.next = node
        print("Insert element after node successfully.")
            
    def delete_at_beg(self):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            self.start = self.start.next
        print("Deletion beginning successfully.")
    
    def delete_at_last(self):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            temp = self.start 
            prev = None
            while(temp.next!=None):
                prev = temp
                temp = temp.next
            if(prev is None):
                self.strat = None
            else:
                prev.next = None
        print("Deletion last successfully.")
            
    def delete_after_desired_node(self,elem):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            temp = self.start
            prev = None
            while(temp is not None and temp.info!=elem):
                prev = temp
                temp = temp.next
            if(temp is None):
                print("Element is does not exists in LinkedList")
            else:
                if(prev is None):
                    self.start = self.strat.next
                else:
                    prev.next = temp.next
        print("Deletion after node successfully.")
            
    def search(self,elem):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            temp = self.start
            while(temp is not None and temp.info!=elem):
                temp = temp.next
            if(temp is not None):
                print("Element found in Linkedlist")
            else:
                print("Element not found in Linkedlist")
            
    def sort(self):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            i= self.start
            while(i.next is not None):
                j = i.next
                while(j is not None):
                    if(i.info>j.info):
                        temp  = i.info
                        i.info = j.info
                        j.info = temp
                    j= j.next
                i = i.next
            print("LinkedList sorted successfully.")
            
    def reversal(self):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            prev = None
            curr = self.start
            while(curr is not None):
                temp = curr.next
                curr.next = prev
                prev = curr
                curr = temp
            self.start = prev 
            print("Reversal successfully.")
        
    def display(self):
        temp = self.start
        while(temp.next!=None):
            print(temp.info,end = "--->")
            temp = temp.next
        print(temp.info)
        print("Linked list displayed successfully.")

# %% [markdown]
# ### Give choice for user

# %%
def program():
    SLL = Linkedlist()
    while(True): 
        print("""<***************************** LINKEDLIST PROGRAM *****************************>
          1.Create Linkedlist
          2.Insert at beginning
          3.Insert at last
          4.Insert at desired location
          5.Deletion at beginning
          6.Deletion at last
          7.Deletion at desired location
          8.Searching
          9.Sorting
          10.Reversal
          11.Display""")
        choice = int(input("Enter your choice: "))
        if(choice==1):
            SLL.create()
        elif(choice==2):
            SLL.insert_at_beg()
        elif(choice==3):
            SLL.insert_at_last()
        elif(choice==4):
            elem = input("Enter element where u want to insert next element: ")
            SLL.insert_after_desired_node(elem)
        elif(choice==5):
            SLL.delete_at_beg()
        elif(choice==6):
            SLL.delete_at_last()
        elif(choice==7):
            elem = input("Enter element which u want to delete: ")
            SLL.delete_after_desired_node(elem)
        elif(choice==8):
            elem = input("Enter element which u want to search: ")
            SLL.search(elem)
        elif(choice==9):
            SLL.sort()
        elif(choice==10):
            SLL.reversal()
        elif(choice==11):
            SLL.display()
        elif(choice==12):
            print("Thanks for using my LINKEDLIST PROGRAM: -)")
            break
        else:
            print("Wrong choice......Please Enter correct choice")
program()
# Out:
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 1
# Enter info: 15
# Do u want to next node? yes/no : yes
# Enter info: 78
# Do u want to next node? yes/no : yes
# Enter info: 46
# Do u want to next node? yes/no : no
# Linkedlist created successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 11
# 15--->78--->46
# Linked list displayed successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 12
# Thanks for using my LINKEDLIST PROGRAM: -)

# %%
program()
# Out:
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 1
# Enter info: 12
# Do u want to next node? yes/no : yes
# Enter info: 45
# Do u want to next node? yes/no : yes
# Enter info: 71
# Do u want to next node? yes/no : no
# Linkedlist created successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 2
# Enter element which u want to insert at beginning: 13
# Insert element at beginning successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 11
# 13--->12--->45--->71
# Linked list displayed successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 12
# Thanks for using my LINKEDLIST PROGRAM: -)

# %%
program()
# Out:
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 1
# Enter info: 34
# Do u want to next node? yes/no : yes
# Enter info: 71
# Do u want to next node? yes/no : yes
# Enter info: 90
# Do u want to next node? yes/no : no
# Linkedlist created successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 3
# Enter element which u want to insert at last: 99
# Insert element at last successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 11
# 34--->71--->90--->99
# Linked list displayed successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 4
# Enter element where u want to insert next element: 90
# Enter element which u want to insert after node: 12
# Insert element after node successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 11
# 34--->71--->90--->12--->99
# Linked list displayed successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 5
# Deletion beginning successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 11
# 71--->90--->12--->99
# Linked list displayed successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 12
# Thanks for using my LINKEDLIST PROGRAM: -)

# %%
program()
# Out:
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 1
# Enter info: 13
# Do u want to next node? yes/no : yes
# Enter info: 88
# Do u want to next node? yes/no : yes
# Enter info: 15
# Do u want to next node? yes/no : no
# Linkedlist created successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 6
# Deletion last successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 11
# 13--->88
# Linked list displayed successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 7
# Enter element which u want to delete: 88
# Deletion after node successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 11
# 13
# Linked list displayed successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 12
# Thanks for using my LINKEDLIST PROGRAM: -)

# %%
program()
# Out:
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 1
# Enter info: 45
# Do u want to next node? yes/no : yes
# Enter info: 13
# Do u want to next node? yes/no : yes
# Enter info: 56
# Do u want to next node? yes/no : no
# Linkedlist created successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 8
# Enter element which u want to search: 56
# Element found in Linkedlist
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 11
# 45--->13--->56
# Linked list displayed successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 9
# LinkedList sorted successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 11
# 13--->45--->56
# Linked list displayed successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 10
# Reversal successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 11
# 56--->45--->13
# Linked list displayed successfully.
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
# Enter your choice: 12
# Thanks for using my LINKEDLIST PROGRAM: -)
